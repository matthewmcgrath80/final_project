# %%
#With sampling

import torch
import torchvision.transforms as transforms
from torchvision.transforms import v2
from PIL import Image
import torchvision.models as models
import matplotlib.pyplot as plt
import os
import pandas as pd
from torch.utils.data import Dataset, DataLoader, Subset, WeightedRandomSampler
from torchmetrics.classification import MulticlassRecall, MulticlassPrecision, MulticlassSpecificity, MulticlassF1Score
from sklearn.model_selection import StratifiedShuffleSplit
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay, precision_recall_curve, PrecisionRecallDisplay, roc_curve, RocCurveDisplay
from collections import Counter

# Image transformer

train_transform = v2.Compose([
    v2.Resize(256),
    v2.CenterCrop(224),
    v2.RandomHorizontalFlip(),
    v2.RandomRotation(10),
    v2.ToImage(),
    v2.ToDtype(torch.float32, scale=True),
    v2.Normalize(
        mean=[0.485, 0.456, 0.406], 
        std=[0.229, 0.224, 0.225]
    )
])

test_transform = v2.Compose([
    v2.Resize(256),
    v2.CenterCrop(224),
    v2.ToImage(),
    v2.ToDtype(torch.float32, scale=True),
    v2.Normalize(
        mean=[0.485, 0.456, 0.406], 
        std=[0.229, 0.224, 0.225]
    )
])

# Creates a custom dataset. Initialised with the csv file, image file and transformeded.

class messidorDataset(Dataset):
    def __init__(self, annotations_file, img_dir, transform=None):
        self.img_labels = pd.read_csv(annotations_file)
        self.img_dir = img_dir
        self.transform = transform

    def __len__(self):
        return len(self.img_labels)
    
    def __getitem__(self, idx):
        img_path = os.path.join(self.img_dir, self.img_labels.iloc[idx,0])
        image = Image.open(img_path).convert("RGB")
        label = int(self.img_labels.iloc[idx, 1])
        if self.transform:
            image = self.transform(image)
        return image, label

# Get the images and csv data file

annotations_file = "/mnt/c/Users/matth/CS408/MESSIDOR-2_from_kaggle/messidor_data_without_3_4.csv"
img_dir = "/mnt/c/Users/matth/CS408/MESSIDOR-2_from_kaggle/messidor-2/preprocess"
af = pd.read_csv(annotations_file)
num_imgs = len(af)
label = af.iloc[:, 1].values
indices = np.arange(len(af))

# Splits the dataset into training and testing sets in 80:20 ratio respectively

sss = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
train_index, test_index = next(sss.split(indices, label))

training_dataset = messidorDataset(annotations_file, img_dir, train_transform)
testing_dataset = messidorDataset(annotations_file, img_dir, test_transform)

train_dataset = Subset(training_dataset, train_index)
test_dataset = Subset(testing_dataset, test_index)

targets = training_dataset.img_labels.iloc[train_dataset.indices, 1].values
num_samples = len(targets)
class_counts = torch.bincount(torch.tensor(targets))
sample_weights = torch.tensor([1.0 / class_counts[t] for t in targets])
train_sampler = WeightedRandomSampler(weights=sample_weights, num_samples=num_samples, replacement=True)

labels = testing_dataset.img_labels.iloc[test_dataset.indices, 1].values
unique, counts = np.unique(labels, return_counts=True)

for u, c in zip(unique, counts):
    print(f"Class {u}: {c}")

# Loads the dataset, batchsize and shuffles the dataset

train_loader = DataLoader(train_dataset, batch_size=64, sampler=train_sampler)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

class_counter = Counter()

for inputs, labels in train_loader:
    class_counter.update(labels.tolist())

print("Sampled class counts in one epoch:")
for cls in sorted(class_counter.keys()):
    print(f"Class {cls}: {class_counter[cls]}")

# Load ResNet18

model = models.resnet18(weights=models.ResNet18_Weights.IMAGENET1K_V1)

# This replaces the final layer of the model to output 5 classes instead of 1000

model.fc = torch.nn.Linear(
    in_features=model.fc.in_features,
    out_features=3
)

# Freeze all layers except the last two layers.

for param in model.parameters():
    param.requires_grad = False
for param in model.layer3.parameters():
    param.requires_grad = True
for param in model.layer4.parameters():
    param.requires_grad = True
for param in model.fc.parameters():
    param.requires_grad = True

# Uses cuda if available or it uses cpu

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)

# Loss function and optimizer

criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam([
    {"params": model.layer3.parameters(), "lr": 1e-4},
    {"params": model.layer4.parameters(), "lr": 1e-4},
    {"params": model.fc.parameters(), "lr": 1e-3},
])

# Model training

total_epoch = 15
recall_macro = MulticlassRecall(num_classes=3, average="macro").to(device)
precision_macro = MulticlassPrecision(num_classes=3, average="macro").to(device)
specificity_macro = MulticlassSpecificity(num_classes=3, average="macro").to(device)
f1score_macro = MulticlassF1Score(num_classes=3, average="macro").to(device)
train_probs = []
pred_val = []
all_labels = []
for epoch in range(total_epoch):
    model.train()
    recall_macro.reset()
    precision_macro.reset()
    specificity_macro.reset()
    f1score_macro.reset()
    running_loss = 0.0
    correct = 0
    total = 0
    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        
        optimizer.zero_grad()

        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        _, predicted = outputs.max(1)
        if epoch == total_epoch-1:
            probs = torch.softmax(outputs, dim=1)
            train_probs.append(probs.detach().numpy())
            pred_val.append(predicted.detach().numpy())
            all_labels.append(labels.detach().numpy())
        correct += predicted.eq(labels).sum().item()
        total += labels.size(0)
        recall_macro.update(predicted, labels)
        precision_macro.update(predicted, labels)
        specificity_macro.update(predicted, labels)
        f1score_macro.update(predicted, labels)

    recall = recall_macro.compute().item()
    precision = precision_macro.compute().item()
    specificity = specificity_macro.compute().item()
    f1score = f1score_macro.compute().item()
    print(f'Epoch [{epoch+1}/{total_epoch}], Loss: {running_loss/len(train_loader):.4f}, Accuracy: {100 * correct / total:.2f}%, Recall: {recall:.2f}, Precision: {precision:.2f}, Specificity: {specificity:.2f}, F1-Score: {f1score:.2f}')
train_probs = np.concatenate(train_probs, axis=0)
pred_val = np.concatenate(pred_val, axis=0)
all_labels = np.concatenate(all_labels, axis=0)
print("Classification Report:\n", classification_report(all_labels, pred_val, labels=[0,1,2]))
cm = confusion_matrix(all_labels, pred_val, labels=[0,1,2], normalize='true')
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[0,1,2])
disp.plot()
plt.show()

plt.figure(figsize=(8,6))
for c in range(3):
    precision, recall, _ = precision_recall_curve(
        (all_labels == c).astype(int),
        train_probs[:, c]
    )
    plt.plot(recall, precision, label=f"Class {c}")

plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision–Recall Curve (Training – Last Epoch)")
plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(8,6))
for c in range(3):
    false_pos, true_pos, _ = roc_curve(
        (all_labels == c).astype(int),
        train_probs[:, c]
    )
    plt.plot(false_pos, true_pos, label=f"Class {c}")

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive rate")
plt.title("ROC Curve (Training – Last Epoch)")
plt.legend()
plt.grid(True)
plt.show()

model.eval()
recall_macro.reset()
precision_macro.reset()
specificity_macro.reset()
f1score_macro.reset()
correct = 0
total = 0
test_probs = []
pred_val = []
all_labels = []

# Model testing

with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, predicted = outputs.max(1)
        probs = torch.softmax(outputs, dim=1)
        test_probs.append(probs.numpy())
        pred_val.append(predicted.numpy())
        all_labels.append(labels.numpy())
        correct += predicted.eq(labels).sum().item()
        total += labels.size(0)
        recall_macro.update(predicted, labels)
        precision_macro.update(predicted, labels)
        specificity_macro.update(predicted, labels)
        f1score_macro.update(predicted, labels)
    recall = recall_macro.compute().item()
    precision = precision_macro.compute().item()
    specificity = specificity_macro.compute().item()
    f1score = f1score_macro.compute().item()
print(f'Test Accuracy: {100 * correct / total:.2f}%, Recall: {recall:.2f}, Precision: {precision:.2f}, Specificity: {specificity:.2f}, F1-Score: {f1score:.2f}')
test_probs = np.concatenate(test_probs, axis=0)
all_labels = np.concatenate(all_labels, axis=0)
pred_val = np.concatenate(pred_val, axis=0)
print("Classification Report:\n", classification_report(all_labels, pred_val, labels=[0,1,2]))
cm = confusion_matrix(all_labels, pred_val, labels=[0,1,2], normalize='true')
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[0,1,2])
disp.plot()
plt.show()

plt.figure(figsize=(8,6))

for c in range(3):
    precision, recall, _ = precision_recall_curve(
        (all_labels == c).astype(int),
        test_probs[:, c]
    )
    plt.plot(recall, precision, label=f"Class {c}")

plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision–Recall Curve (Test Set)")
plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(8,6))
for c in range(3):
    false_pos, true_pos, _ = roc_curve(
        (all_labels == c).astype(int),
        test_probs[:, c]
    )
    plt.plot(false_pos, true_pos, label=f"Class {c}")

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive rate")
plt.title("ROC Curve (Test Set)")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Class 0: 204
# Class 1: 54
# Class 2: 69
# Sampled class counts in one epoch:
# Class 0: 440
# Class 1: 429
# Class 2: 438
# Epoch [1/15], Loss: 0.9947, Accuracy: 50.57%, Recall: 0.51, Precision: 0.51, Specificity: 0.75, F1-Score: 0.51
# Epoch [2/15], Loss: 0.7935, Accuracy: 64.19%, Recall: 0.64, Precision: 0.64, Specificity: 0.82, F1-Score: 0.64
# Epoch [3/15], Loss: 0.6125, Accuracy: 74.67%, Recall: 0.75, Precision: 0.74, Specificity: 0.87, F1-Score: 0.74
# Epoch [4/15], Loss: 0.4340, Accuracy: 83.01%, Recall: 0.83, Precision: 0.83, Specificity: 0.92, F1-Score: 0.83
# Epoch [5/15], Loss: 0.3296, Accuracy: 88.14%, Recall: 0.88, Precision: 0.88, Specificity: 0.94, F1-Score: 0.88
# Epoch [6/15], Loss: 0.2423, Accuracy: 91.43%, Recall: 0.92, Precision: 0.91, Specificity: 0.96, F1-Score: 0.91
# Epoch [7/15], Loss: 0.1895, Accuracy: 93.34%, Recall: 0.93, Precision: 0.93, Specificity: 0.97, F1-Score: 0.93
# Epoch [8/15], Loss: 0.1644, Accuracy: 94.49%, Recall: 0.94, Precision: 0.95, Specificity: 0.97, F1-Score: 0.95
# Epoch [9/15], Loss: 0.1660, Accuracy: 94.49%, Recall: 0.95, Precision: 0.95, Specificity: 0.97, F1-Score: 0.95
# Epoch [10/15], Loss: 0.1273, Accuracy: 96.10%, Recall: 0.96, Precision: 0.96, Specificity: 0.98, F1-Score: 0.96
# Epoch [11/15], Loss: 0.1124, Accuracy: 96.10%, Recall: 0.96, Precision: 0.96, Specificity: 0.98, F1-Score: 0.96
# Epoch [12/15], Loss: 0.1047, Accuracy: 96.71%, Recall: 0.97, Precision: 0.97, Specificity: 0.98, F1-Score: 0.97
# Epoch [13/15], Loss: 0.0702, Accuracy: 97.86%, Recall: 0.98, Precision: 0.98, Specificity: 0.99, F1-Score: 0.98
# Epoch [14/15], Loss: 0.0674, Accuracy: 98.01%, Recall: 0.98, Precision: 0.98, Specificity: 0.99, F1-Score: 0.98
# Epoch [15/15], Loss: 0.0463, Accuracy: 98.47%, Recall: 0.98, Precision: 0.98, Specificity: 0.99, F1-Score: 0.98
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       429
#            1       0.99      0.99      0.99       433
#            2       0.98      0.99      0.99       445
#
#     accuracy                           0.98      1307
#    macro avg       0.98      0.98      0.98      1307
# weighted avg       0.98      0.98      0.98      1307
# Test Accuracy: 70.95%, Recall: 0.52, Precision: 0.63, Specificity: 0.78, F1-Score: 0.54
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.73      0.94      0.82       204
#            1       0.33      0.17      0.22        54
#            2       0.82      0.45      0.58        69
#
#     accuracy                           0.71       327
#    macro avg       0.63      0.52      0.54       327
# weighted avg       0.68      0.71      0.67       327

# %%
#Improved data augmentation

import torch
import torchvision.transforms as transforms
from torchvision.transforms import v2
from PIL import Image
import torchvision.models as models
import matplotlib.pyplot as plt
import os
import pandas as pd
from torch.utils.data import Dataset, DataLoader, Subset, WeightedRandomSampler
from torchmetrics.classification import MulticlassRecall, MulticlassPrecision, MulticlassSpecificity, MulticlassF1Score
from sklearn.model_selection import StratifiedShuffleSplit
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay, precision_recall_curve, PrecisionRecallDisplay, roc_curve, RocCurveDisplay
from collections import Counter

# Image transformer

train_transform = v2.Compose([
    v2.Resize(256),
    v2.RandomResizedCrop(
        size=224,
        scale=(0.8, 1.0),
        ratio=(0.9, 1.1)
    ),
    v2.RandomHorizontalFlip(),
    v2.RandomRotation(15),
    v2.ColorJitter(
        brightness=0.3,
        contrast=0.3,
        saturation=0.2,
        hue=0.02
    ),
    v2.GaussianBlur(
        kernel_size=3,
        sigma=(0.1, 2.0)
    ),
    v2.ToImage(),
    v2.ToDtype(
        torch.float32,
        scale=True
    ),
    v2.Normalize(
        mean=[0.485, 0.456, 0.406], 
        std=[0.229, 0.224, 0.225]
    ),
    v2.RandomErasing(
        p=0.25,
        scale=(0.02, 0.1),
        ratio=(0.3, 3.3),
        value='random'
    )
])

test_transform = v2.Compose([
    v2.Resize(256),
    v2.CenterCrop(224),
    v2.ToImage(),
    v2.ToDtype(torch.float32, scale=True),
    v2.Normalize(
        mean=[0.485, 0.456, 0.406], 
        std=[0.229, 0.224, 0.225]
    )
])

# Creates a custom dataset. Initialised with the csv file, image file and transformeded.

class messidorDataset(Dataset):
    def __init__(self, annotations_file, img_dir, transform=None):
        self.img_labels = pd.read_csv(annotations_file)
        self.img_dir = img_dir
        self.transform = transform

    def __len__(self):
        return len(self.img_labels)
    
    def __getitem__(self, idx):
        img_path = os.path.join(self.img_dir, self.img_labels.iloc[idx,0])
        image = Image.open(img_path).convert("RGB")
        label = int(self.img_labels.iloc[idx, 1])
        if self.transform:
            image = self.transform(image)
        return image, label

# Get the images and csv data file

annotations_file = "/mnt/c/Users/matth/CS408/MESSIDOR-2_from_kaggle/messidor_data_without_3_4.csv"
img_dir = "/mnt/c/Users/matth/CS408/MESSIDOR-2_from_kaggle/messidor-2/preprocess"
af = pd.read_csv(annotations_file)
num_imgs = len(af)
label = af.iloc[:, 1].values
indices = np.arange(len(af))

# Splits the dataset into training and testing sets in 80:20 ratio respectively

sss = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
train_index, test_index = next(sss.split(indices, label))

training_dataset = messidorDataset(annotations_file, img_dir, train_transform)
testing_dataset = messidorDataset(annotations_file, img_dir, test_transform)

train_dataset = Subset(training_dataset, train_index)
test_dataset = Subset(testing_dataset, test_index)

targets = training_dataset.img_labels.iloc[train_dataset.indices, 1].values
num_samples = len(targets)
class_counts = torch.bincount(torch.tensor(targets))
sample_weights = torch.tensor([1.0 / class_counts[t] for t in targets])
train_sampler = WeightedRandomSampler(weights=sample_weights, num_samples=num_samples, replacement=True)

labels = testing_dataset.img_labels.iloc[test_dataset.indices, 1].values
unique, counts = np.unique(labels, return_counts=True)

for u, c in zip(unique, counts):
    print(f"Class {u}: {c}")

# Loads the dataset, batchsize and shuffles the dataset

train_loader = DataLoader(train_dataset, batch_size=64, sampler=train_sampler)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

class_counter = Counter()

for inputs, labels in train_loader:
    class_counter.update(labels.tolist())

print("Sampled class counts in one epoch:")
for cls in sorted(class_counter.keys()):
    print(f"Class {cls}: {class_counter[cls]}")

# Load ResNet18

model = models.resnet18(weights=models.ResNet18_Weights.IMAGENET1K_V1)

# This replaces the final layer of the model to output 5 classes instead of 1000

model.fc = torch.nn.Linear(
    in_features=model.fc.in_features,
    out_features=3
)

# Freeze all layers except the last two layers.

for param in model.parameters():
    param.requires_grad = False
for param in model.layer3.parameters():
    param.requires_grad = True
for param in model.layer4.parameters():
    param.requires_grad = True
for param in model.fc.parameters():
    param.requires_grad = True

# Uses cuda if available or it uses cpu

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)

# Loss function and optimizer

criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam([
    {"params": model.layer3.parameters(), "lr": 1e-4},
    {"params": model.layer4.parameters(), "lr": 1e-4},
    {"params": model.fc.parameters(), "lr": 1e-3},
])

# Model training

total_epoch = 25
recall_macro = MulticlassRecall(num_classes=3, average="macro").to(device)
precision_macro = MulticlassPrecision(num_classes=3, average="macro").to(device)
specificity_macro = MulticlassSpecificity(num_classes=3, average="macro").to(device)
f1score_macro = MulticlassF1Score(num_classes=3, average="macro").to(device)
train_probs = []
pred_val = []
all_labels = []
for epoch in range(total_epoch):
    model.train()
    recall_macro.reset()
    precision_macro.reset()
    specificity_macro.reset()
    f1score_macro.reset()
    running_loss = 0.0
    correct = 0
    total = 0
    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        
        optimizer.zero_grad()

        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        _, predicted = outputs.max(1)
        if epoch == total_epoch-1:
            probs = torch.softmax(outputs, dim=1)
            train_probs.append(probs.detach().numpy())
            pred_val.append(predicted.detach().numpy())
            all_labels.append(labels.detach().numpy())
        correct += predicted.eq(labels).sum().item()
        total += labels.size(0)
        recall_macro.update(predicted, labels)
        precision_macro.update(predicted, labels)
        specificity_macro.update(predicted, labels)
        f1score_macro.update(predicted, labels)

    recall = recall_macro.compute().item()
    precision = precision_macro.compute().item()
    specificity = specificity_macro.compute().item()
    f1score = f1score_macro.compute().item()
    print(f'Epoch [{epoch+1}/{total_epoch}], Loss: {running_loss/len(train_loader):.4f}, Accuracy: {100 * correct / total:.2f}%, Recall: {recall:.2f}, Precision: {precision:.2f}, Specificity: {specificity:.2f}, F1-Score: {f1score:.2f}')
train_probs = np.concatenate(train_probs, axis=0)
pred_val = np.concatenate(pred_val, axis=0)
all_labels = np.concatenate(all_labels, axis=0)
print("Classification Report:\n", classification_report(all_labels, pred_val, labels=[0,1,2]))
cm = confusion_matrix(all_labels, pred_val, labels=[0,1,2], normalize='true')
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[0,1,2])
disp.plot()
plt.show()

plt.figure(figsize=(8,6))
for c in range(3):
    precision, recall, _ = precision_recall_curve(
        (all_labels == c).astype(int),
        train_probs[:, c]
    )
    plt.plot(recall, precision, label=f"Class {c}")

plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision–Recall Curve (Training – Last Epoch)")
plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(8,6))
for c in range(3):
    false_pos, true_pos, _ = roc_curve(
        (all_labels == c).astype(int),
        train_probs[:, c]
    )
    plt.plot(false_pos, true_pos, label=f"Class {c}")

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive rate")
plt.title("ROC Curve (Training – Last Epoch)")
plt.legend()
plt.grid(True)
plt.show()

model.eval()
recall_macro.reset()
precision_macro.reset()
specificity_macro.reset()
f1score_macro.reset()
correct = 0
total = 0
test_probs = []
pred_val = []
all_labels = []

# Model testing

with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, predicted = outputs.max(1)
        probs = torch.softmax(outputs, dim=1)
        test_probs.append(probs.numpy())
        pred_val.append(predicted.numpy())
        all_labels.append(labels.numpy())
        correct += predicted.eq(labels).sum().item()
        total += labels.size(0)
        recall_macro.update(predicted, labels)
        precision_macro.update(predicted, labels)
        specificity_macro.update(predicted, labels)
        f1score_macro.update(predicted, labels)
    recall = recall_macro.compute().item()
    precision = precision_macro.compute().item()
    specificity = specificity_macro.compute().item()
    f1score = f1score_macro.compute().item()
print(f'Test Accuracy: {100 * correct / total:.2f}%, Recall: {recall:.2f}, Precision: {precision:.2f}, Specificity: {specificity:.2f}, F1-Score: {f1score:.2f}')
test_probs = np.concatenate(test_probs, axis=0)
all_labels = np.concatenate(all_labels, axis=0)
pred_val = np.concatenate(pred_val, axis=0)
print("Classification Report:\n", classification_report(all_labels, pred_val, labels=[0,1,2]))
cm = confusion_matrix(all_labels, pred_val, labels=[0,1,2], normalize='true')
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[0,1,2])
disp.plot()
plt.show()

plt.figure(figsize=(8,6))

for c in range(3):
    precision, recall, _ = precision_recall_curve(
        (all_labels == c).astype(int),
        test_probs[:, c]
    )
    plt.plot(recall, precision, label=f"Class {c}")

plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision–Recall Curve (Test Set)")
plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(8,6))
for c in range(3):
    false_pos, true_pos, _ = roc_curve(
        (all_labels == c).astype(int),
        test_probs[:, c]
    )
    plt.plot(false_pos, true_pos, label=f"Class {c}")

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive rate")
plt.title("ROC Curve (Test Set)")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Class 0: 204
# Class 1: 54
# Class 2: 69
# Sampled class counts in one epoch:
# Class 0: 452
# Class 1: 434
# Class 2: 421
# Epoch [1/25], Loss: 1.0739, Accuracy: 43.76%, Recall: 0.44, Precision: 0.44, Specificity: 0.72, F1-Score: 0.44
# Epoch [2/25], Loss: 0.9736, Accuracy: 52.56%, Recall: 0.52, Precision: 0.52, Specificity: 0.76, F1-Score: 0.52
# Epoch [3/25], Loss: 0.9067, Accuracy: 56.01%, Recall: 0.56, Precision: 0.56, Specificity: 0.78, F1-Score: 0.56
# Epoch [4/25], Loss: 0.8380, Accuracy: 59.30%, Recall: 0.59, Precision: 0.59, Specificity: 0.80, F1-Score: 0.59
# Epoch [5/25], Loss: 0.7731, Accuracy: 65.11%, Recall: 0.65, Precision: 0.65, Specificity: 0.83, F1-Score: 0.65
# Epoch [6/25], Loss: 0.7551, Accuracy: 66.18%, Recall: 0.66, Precision: 0.66, Specificity: 0.83, F1-Score: 0.66
# Epoch [7/25], Loss: 0.7258, Accuracy: 67.41%, Recall: 0.67, Precision: 0.67, Specificity: 0.84, F1-Score: 0.67
# Epoch [8/25], Loss: 0.6879, Accuracy: 69.85%, Recall: 0.70, Precision: 0.70, Specificity: 0.85, F1-Score: 0.70
# Epoch [9/25], Loss: 0.6316, Accuracy: 73.30%, Recall: 0.73, Precision: 0.73, Specificity: 0.87, F1-Score: 0.73
# Epoch [10/25], Loss: 0.5649, Accuracy: 75.52%, Recall: 0.76, Precision: 0.76, Specificity: 0.88, F1-Score: 0.76
# Epoch [11/25], Loss: 0.5257, Accuracy: 78.96%, Recall: 0.79, Precision: 0.79, Specificity: 0.89, F1-Score: 0.79
# Epoch [12/25], Loss: 0.5272, Accuracy: 78.73%, Recall: 0.79, Precision: 0.79, Specificity: 0.89, F1-Score: 0.79
# Epoch [13/25], Loss: 0.4571, Accuracy: 81.03%, Recall: 0.81, Precision: 0.81, Specificity: 0.91, F1-Score: 0.81
# Epoch [14/25], Loss: 0.4266, Accuracy: 83.70%, Recall: 0.84, Precision: 0.84, Specificity: 0.92, F1-Score: 0.84
# Epoch [15/25], Loss: 0.3790, Accuracy: 84.54%, Recall: 0.85, Precision: 0.85, Specificity: 0.92, F1-Score: 0.85
# Epoch [16/25], Loss: 0.3965, Accuracy: 84.09%, Recall: 0.84, Precision: 0.84, Specificity: 0.92, F1-Score: 0.84
# Epoch [17/25], Loss: 0.3354, Accuracy: 86.30%, Recall: 0.86, Precision: 0.86, Specificity: 0.93, F1-Score: 0.86
# Epoch [18/25], Loss: 0.3378, Accuracy: 86.46%, Recall: 0.86, Precision: 0.87, Specificity: 0.93, F1-Score: 0.86
# Epoch [19/25], Loss: 0.3347, Accuracy: 86.23%, Recall: 0.86, Precision: 0.86, Specificity: 0.93, F1-Score: 0.86
# Epoch [20/25], Loss: 0.3285, Accuracy: 87.53%, Recall: 0.88, Precision: 0.88, Specificity: 0.94, F1-Score: 0.88
# Epoch [21/25], Loss: 0.2847, Accuracy: 88.83%, Recall: 0.89, Precision: 0.89, Specificity: 0.94, F1-Score: 0.89
# Epoch [22/25], Loss: 0.2567, Accuracy: 90.59%, Recall: 0.91, Precision: 0.91, Specificity: 0.95, F1-Score: 0.91
# Epoch [23/25], Loss: 0.2350, Accuracy: 91.28%, Recall: 0.91, Precision: 0.91, Specificity: 0.96, F1-Score: 0.91
# Epoch [24/25], Loss: 0.2515, Accuracy: 91.20%, Recall: 0.91, Precision: 0.91, Specificity: 0.96, F1-Score: 0.91
# Epoch [25/25], Loss: 0.2450, Accuracy: 90.36%, Recall: 0.90, Precision: 0.90, Specificity: 0.95, F1-Score: 0.90
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.89      0.89       449
#            1       0.88      0.91      0.90       416
#            2       0.93      0.91      0.92       442
#
#     accuracy                           0.90      1307
#    macro avg       0.90      0.90      0.90      1307
# weighted avg       0.90      0.90      0.90      1307
# Test Accuracy: 67.28%, Recall: 0.56, Precision: 0.59, Specificity: 0.80, F1-Score: 0.57
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.79      0.81      0.80       204
#            1       0.28      0.33      0.30        54
#            2       0.70      0.54      0.61        69
#
#     accuracy                           0.67       327
#    macro avg       0.59      0.56      0.57       327
# weighted avg       0.69      0.67      0.68       327

# %%
#Improved data augmentation and label smoothing

import torch
import torchvision.transforms as transforms
from torchvision.transforms import v2
from PIL import Image
import torchvision.models as models
import matplotlib.pyplot as plt
import os
import pandas as pd
from torch.utils.data import Dataset, DataLoader, Subset, WeightedRandomSampler
from torchmetrics.classification import MulticlassRecall, MulticlassPrecision, MulticlassSpecificity, MulticlassF1Score
from sklearn.model_selection import StratifiedShuffleSplit
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay, precision_recall_curve, PrecisionRecallDisplay, roc_curve, RocCurveDisplay
from collections import Counter

# Image transformer

train_transform = v2.Compose([
    v2.Resize(256),
    v2.RandomResizedCrop(
        size=224,
        scale=(0.8, 1.0),
        ratio=(0.9, 1.1)
    ),
    v2.RandomHorizontalFlip(),
    v2.RandomRotation(15),
    v2.ColorJitter(
        brightness=0.3,
        contrast=0.3,
        saturation=0.2,
        hue=0.02
    ),
    v2.GaussianBlur(
        kernel_size=3,
        sigma=(0.1, 2.0)
    ),
    v2.ToImage(),
    v2.ToDtype(
        torch.float32,
        scale=True
    ),
    v2.Normalize(
        mean=[0.485, 0.456, 0.406], 
        std=[0.229, 0.224, 0.225]
    ),
    v2.RandomErasing(
        p=0.25,
        scale=(0.02, 0.1),
        ratio=(0.3, 3.3),
        value='random'
    )
])

test_transform = v2.Compose([
    v2.Resize(256),
    v2.CenterCrop(224),
    v2.ToImage(),
    v2.ToDtype(torch.float32, scale=True),
    v2.Normalize(
        mean=[0.485, 0.456, 0.406], 
        std=[0.229, 0.224, 0.225]
    )
])

# Creates a custom dataset. Initialised with the csv file, image file and transformeded.

class messidorDataset(Dataset):
    def __init__(self, annotations_file, img_dir, transform=None):
        self.img_labels = pd.read_csv(annotations_file)
        self.img_dir = img_dir
        self.transform = transform

    def __len__(self):
        return len(self.img_labels)
    
    def __getitem__(self, idx):
        img_path = os.path.join(self.img_dir, self.img_labels.iloc[idx,0])
        image = Image.open(img_path).convert("RGB")
        label = int(self.img_labels.iloc[idx, 1])
        if self.transform:
            image = self.transform(image)
        return image, label

# Get the images and csv data file

annotations_file = "/mnt/c/Users/matth/CS408/MESSIDOR-2_from_kaggle/messidor_data_without_3_4.csv"
img_dir = "/mnt/c/Users/matth/CS408/MESSIDOR-2_from_kaggle/messidor-2/preprocess"
af = pd.read_csv(annotations_file)
num_imgs = len(af)
label = af.iloc[:, 1].values
indices = np.arange(len(af))

# Splits the dataset into training and testing sets in 80:20 ratio respectively

sss = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
train_index, test_index = next(sss.split(indices, label))

training_dataset = messidorDataset(annotations_file, img_dir, train_transform)
testing_dataset = messidorDataset(annotations_file, img_dir, test_transform)

train_dataset = Subset(training_dataset, train_index)
test_dataset = Subset(testing_dataset, test_index)

targets = training_dataset.img_labels.iloc[train_dataset.indices, 1].values
num_samples = len(targets)
class_counts = torch.bincount(torch.tensor(targets))
sample_weights = torch.tensor([1.0 / class_counts[t] for t in targets])
train_sampler = WeightedRandomSampler(weights=sample_weights, num_samples=num_samples, replacement=True)

labels = testing_dataset.img_labels.iloc[test_dataset.indices, 1].values
unique, counts = np.unique(labels, return_counts=True)

for u, c in zip(unique, counts):
    print(f"Class {u}: {c}")

# Loads the dataset, batchsize and shuffles the dataset

train_loader = DataLoader(train_dataset, batch_size=64, sampler=train_sampler)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

class_counter = Counter()

for inputs, labels in train_loader:
    class_counter.update(labels.tolist())

print("Sampled class counts in one epoch:")
for cls in sorted(class_counter.keys()):
    print(f"Class {cls}: {class_counter[cls]}")

# Load ResNet18

model = models.resnet18(weights=models.ResNet18_Weights.IMAGENET1K_V1)

# This replaces the final layer of the model to output 5 classes instead of 1000

model.fc = torch.nn.Linear(
    in_features=model.fc.in_features,
    out_features=3
)

# Freeze all layers except the last two layers.

for param in model.parameters():
    param.requires_grad = False
for param in model.layer3.parameters():
    param.requires_grad = True
for param in model.layer4.parameters():
    param.requires_grad = True
for param in model.fc.parameters():
    param.requires_grad = True

# Uses cuda if available or it uses cpu

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)

# Loss function and optimizer

criterion = torch.nn.CrossEntropyLoss(label_smoothing=0.1)
optimizer = torch.optim.Adam([
    {"params": model.layer3.parameters(), "lr": 1e-4},
    {"params": model.layer4.parameters(), "lr": 1e-4},
    {"params": model.fc.parameters(), "lr": 1e-3},
])

# Model training

total_epoch = 25
recall_macro = MulticlassRecall(num_classes=3, average="macro").to(device)
precision_macro = MulticlassPrecision(num_classes=3, average="macro").to(device)
specificity_macro = MulticlassSpecificity(num_classes=3, average="macro").to(device)
f1score_macro = MulticlassF1Score(num_classes=3, average="macro").to(device)
train_probs = []
pred_val = []
all_labels = []
for epoch in range(total_epoch):
    model.train()
    recall_macro.reset()
    precision_macro.reset()
    specificity_macro.reset()
    f1score_macro.reset()
    running_loss = 0.0
    correct = 0
    total = 0
    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        
        optimizer.zero_grad()

        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        _, predicted = outputs.max(1)
        if epoch == total_epoch-1:
            probs = torch.softmax(outputs, dim=1)
            train_probs.append(probs.detach().numpy())
            pred_val.append(predicted.detach().numpy())
            all_labels.append(labels.detach().numpy())
        correct += predicted.eq(labels).sum().item()
        total += labels.size(0)
        recall_macro.update(predicted, labels)
        precision_macro.update(predicted, labels)
        specificity_macro.update(predicted, labels)
        f1score_macro.update(predicted, labels)

    recall = recall_macro.compute().item()
    precision = precision_macro.compute().item()
    specificity = specificity_macro.compute().item()
    f1score = f1score_macro.compute().item()
    print(f'Epoch [{epoch+1}/{total_epoch}], Loss: {running_loss/len(train_loader):.4f}, Accuracy: {100 * correct / total:.2f}%, Recall: {recall:.2f}, Precision: {precision:.2f}, Specificity: {specificity:.2f}, F1-Score: {f1score:.2f}')
train_probs = np.concatenate(train_probs, axis=0)
pred_val = np.concatenate(pred_val, axis=0)
all_labels = np.concatenate(all_labels, axis=0)
print("Classification Report:\n", classification_report(all_labels, pred_val, labels=[0,1,2]))
cm = confusion_matrix(all_labels, pred_val, labels=[0,1,2], normalize='true')
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[0,1,2])
disp.plot()
plt.show()

plt.figure(figsize=(8,6))
for c in range(3):
    precision, recall, _ = precision_recall_curve(
        (all_labels == c).astype(int),
        train_probs[:, c]
    )
    plt.plot(recall, precision, label=f"Class {c}")

plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision–Recall Curve (Training – Last Epoch)")
plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(8,6))
for c in range(3):
    false_pos, true_pos, _ = roc_curve(
        (all_labels == c).astype(int),
        train_probs[:, c]
    )
    plt.plot(false_pos, true_pos, label=f"Class {c}")

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive rate")
plt.title("ROC Curve (Training – Last Epoch)")
plt.legend()
plt.grid(True)
plt.show()

model.eval()
recall_macro.reset()
precision_macro.reset()
specificity_macro.reset()
f1score_macro.reset()
correct = 0
total = 0
test_probs = []
pred_val = []
all_labels = []

# Model testing

with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, predicted = outputs.max(1)
        probs = torch.softmax(outputs, dim=1)
        test_probs.append(probs.numpy())
        pred_val.append(predicted.numpy())
        all_labels.append(labels.numpy())
        correct += predicted.eq(labels).sum().item()
        total += labels.size(0)
        recall_macro.update(predicted, labels)
        precision_macro.update(predicted, labels)
        specificity_macro.update(predicted, labels)
        f1score_macro.update(predicted, labels)
    recall = recall_macro.compute().item()
    precision = precision_macro.compute().item()
    specificity = specificity_macro.compute().item()
    f1score = f1score_macro.compute().item()
print(f'Test Accuracy: {100 * correct / total:.2f}%, Recall: {recall:.2f}, Precision: {precision:.2f}, Specificity: {specificity:.2f}, F1-Score: {f1score:.2f}')
test_probs = np.concatenate(test_probs, axis=0)
all_labels = np.concatenate(all_labels, axis=0)
pred_val = np.concatenate(pred_val, axis=0)
print("Classification Report:\n", classification_report(all_labels, pred_val, labels=[0,1,2]))
cm = confusion_matrix(all_labels, pred_val, labels=[0,1,2], normalize='true')
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[0,1,2])
disp.plot()
plt.show()

plt.figure(figsize=(8,6))

for c in range(3):
    precision, recall, _ = precision_recall_curve(
        (all_labels == c).astype(int),
        test_probs[:, c]
    )
    plt.plot(recall, precision, label=f"Class {c}")

plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision–Recall Curve (Test Set)")
plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(8,6))
for c in range(3):
    false_pos, true_pos, _ = roc_curve(
        (all_labels == c).astype(int),
        test_probs[:, c]
    )
    plt.plot(false_pos, true_pos, label=f"Class {c}")

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive rate")
plt.title("ROC Curve (Test Set)")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Class 0: 204
# Class 1: 54
# Class 2: 69
# Sampled class counts in one epoch:
# Class 0: 441
# Class 1: 464
# Class 2: 402
# Epoch [1/25], Loss: 1.0858, Accuracy: 44.53%, Recall: 0.44, Precision: 0.44, Specificity: 0.72, F1-Score: 0.44
# Epoch [2/25], Loss: 1.0025, Accuracy: 53.79%, Recall: 0.54, Precision: 0.54, Specificity: 0.77, F1-Score: 0.54
# Epoch [3/25], Loss: 0.9178, Accuracy: 60.90%, Recall: 0.61, Precision: 0.60, Specificity: 0.80, F1-Score: 0.60
# Epoch [4/25], Loss: 0.8989, Accuracy: 60.90%, Recall: 0.61, Precision: 0.61, Specificity: 0.80, F1-Score: 0.61
# Epoch [5/25], Loss: 0.8359, Accuracy: 66.34%, Recall: 0.66, Precision: 0.66, Specificity: 0.83, F1-Score: 0.66
# Epoch [6/25], Loss: 0.8131, Accuracy: 68.86%, Recall: 0.69, Precision: 0.69, Specificity: 0.84, F1-Score: 0.69
# Epoch [7/25], Loss: 0.7715, Accuracy: 72.07%, Recall: 0.72, Precision: 0.72, Specificity: 0.86, F1-Score: 0.72
# Epoch [8/25], Loss: 0.7188, Accuracy: 73.76%, Recall: 0.74, Precision: 0.74, Specificity: 0.87, F1-Score: 0.74
# Epoch [9/25], Loss: 0.7218, Accuracy: 74.60%, Recall: 0.75, Precision: 0.75, Specificity: 0.87, F1-Score: 0.75
# Epoch [10/25], Loss: 0.6830, Accuracy: 75.98%, Recall: 0.76, Precision: 0.76, Specificity: 0.88, F1-Score: 0.76
# Epoch [11/25], Loss: 0.6513, Accuracy: 79.27%, Recall: 0.79, Precision: 0.79, Specificity: 0.90, F1-Score: 0.79
# Epoch [12/25], Loss: 0.6284, Accuracy: 81.56%, Recall: 0.81, Precision: 0.82, Specificity: 0.91, F1-Score: 0.81
# Epoch [13/25], Loss: 0.6219, Accuracy: 82.56%, Recall: 0.83, Precision: 0.83, Specificity: 0.91, F1-Score: 0.83
# Epoch [14/25], Loss: 0.6255, Accuracy: 81.71%, Recall: 0.82, Precision: 0.82, Specificity: 0.91, F1-Score: 0.82
# Epoch [15/25], Loss: 0.5904, Accuracy: 84.77%, Recall: 0.85, Precision: 0.85, Specificity: 0.92, F1-Score: 0.85
# Epoch [16/25], Loss: 0.5401, Accuracy: 87.53%, Recall: 0.88, Precision: 0.88, Specificity: 0.94, F1-Score: 0.88
# Epoch [17/25], Loss: 0.5414, Accuracy: 87.53%, Recall: 0.88, Precision: 0.87, Specificity: 0.94, F1-Score: 0.88
# Epoch [18/25], Loss: 0.5324, Accuracy: 88.22%, Recall: 0.88, Precision: 0.88, Specificity: 0.94, F1-Score: 0.88
# Epoch [19/25], Loss: 0.5235, Accuracy: 86.84%, Recall: 0.87, Precision: 0.87, Specificity: 0.93, F1-Score: 0.87
# Epoch [20/25], Loss: 0.5189, Accuracy: 88.29%, Recall: 0.88, Precision: 0.88, Specificity: 0.94, F1-Score: 0.88
# Epoch [21/25], Loss: 0.5014, Accuracy: 89.82%, Recall: 0.90, Precision: 0.90, Specificity: 0.95, F1-Score: 0.90
# Epoch [22/25], Loss: 0.5139, Accuracy: 89.52%, Recall: 0.90, Precision: 0.89, Specificity: 0.95, F1-Score: 0.90
# Epoch [23/25], Loss: 0.4821, Accuracy: 91.20%, Recall: 0.91, Precision: 0.91, Specificity: 0.96, F1-Score: 0.91
# Epoch [24/25], Loss: 0.4782, Accuracy: 91.51%, Recall: 0.92, Precision: 0.91, Specificity: 0.96, F1-Score: 0.91
# Epoch [25/25], Loss: 0.4526, Accuracy: 93.27%, Recall: 0.93, Precision: 0.93, Specificity: 0.97, F1-Score: 0.93
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.92      0.91       428
#            1       0.94      0.93      0.93       442
#            2       0.96      0.95      0.95       437
#
#     accuracy                           0.93      1307
#    macro avg       0.93      0.93      0.93      1307
# weighted avg       0.93      0.93      0.93      1307
# Test Accuracy: 70.34%, Recall: 0.56, Precision: 0.58, Specificity: 0.81, F1-Score: 0.57
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.79      0.86      0.82       204
#            1       0.24      0.19      0.21        54
#            2       0.71      0.64      0.67        69
#
#     accuracy                           0.70       327
#    macro avg       0.58      0.56      0.57       327
# weighted avg       0.68      0.70      0.69       327

# %%
#Improved data augmentation, Label smoothing, dropout and feature reduction

import torch
from torch import nn
import torchvision.transforms as transforms
from torchvision.transforms import v2
from PIL import Image
import torchvision.models as models
import matplotlib.pyplot as plt
import os
import pandas as pd
from torch.utils.data import Dataset, DataLoader, Subset, WeightedRandomSampler
from torchmetrics.classification import MulticlassRecall, MulticlassPrecision, MulticlassSpecificity, MulticlassF1Score
from sklearn.model_selection import StratifiedShuffleSplit
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay, precision_recall_curve, PrecisionRecallDisplay, roc_curve, RocCurveDisplay
from collections import Counter

# Image transformer

train_transform = v2.Compose([
    v2.Resize(256),
    v2.RandomResizedCrop(
        size=224,
        scale=(0.8, 1.0),
        ratio=(0.9, 1.1)
    ),
    v2.RandomHorizontalFlip(),
    v2.RandomRotation(15),
    v2.ColorJitter(
        brightness=0.3,
        contrast=0.3,
        saturation=0.2,
        hue=0.02
    ),
    v2.GaussianBlur(
        kernel_size=3,
        sigma=(0.1, 2.0)
    ),
    v2.ToImage(),
    v2.ToDtype(
        torch.float32,
        scale=True
    ),
    v2.Normalize(
        mean=[0.485, 0.456, 0.406], 
        std=[0.229, 0.224, 0.225]
    ),
    v2.RandomErasing(
        p=0.25,
        scale=(0.02, 0.1),
        ratio=(0.3, 3.3),
        value='random'
    )
])

test_transform = v2.Compose([
    v2.Resize(256),
    v2.CenterCrop(224),
    v2.ToImage(),
    v2.ToDtype(torch.float32, scale=True),
    v2.Normalize(
        mean=[0.485, 0.456, 0.406], 
        std=[0.229, 0.224, 0.225]
    )
])

# Creates a custom dataset. Initialised with the csv file, image file and transformeded.

class messidorDataset(Dataset):
    def __init__(self, annotations_file, img_dir, transform=None):
        self.img_labels = pd.read_csv(annotations_file)
        self.img_dir = img_dir
        self.transform = transform

    def __len__(self):
        return len(self.img_labels)
    
    def __getitem__(self, idx):
        img_path = os.path.join(self.img_dir, self.img_labels.iloc[idx,0])
        image = Image.open(img_path).convert("RGB")
        label = int(self.img_labels.iloc[idx, 1])
        if self.transform:
            image = self.transform(image)
        return image, label

# Get the images and csv data file

annotations_file = "/mnt/c/Users/matth/CS408/MESSIDOR-2_from_kaggle/messidor_data_without_3_4.csv"
img_dir = "/mnt/c/Users/matth/CS408/MESSIDOR-2_from_kaggle/messidor-2/preprocess"
af = pd.read_csv(annotations_file)
num_imgs = len(af)
label = af.iloc[:, 1].values
indices = np.arange(len(af))

# Splits the dataset into training and testing sets in 80:20 ratio respectively

sss = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
train_index, test_index = next(sss.split(indices, label))

training_dataset = messidorDataset(annotations_file, img_dir, train_transform)
testing_dataset = messidorDataset(annotations_file, img_dir, test_transform)

train_dataset = Subset(training_dataset, train_index)
test_dataset = Subset(testing_dataset, test_index)

targets = training_dataset.img_labels.iloc[train_dataset.indices, 1].values
num_samples = len(targets)
class_counts = torch.bincount(torch.tensor(targets))
sample_weights = torch.tensor([1.0 / class_counts[t] for t in targets])
train_sampler = WeightedRandomSampler(weights=sample_weights, num_samples=num_samples, replacement=True)

labels = testing_dataset.img_labels.iloc[test_dataset.indices, 1].values
unique, counts = np.unique(labels, return_counts=True)

for u, c in zip(unique, counts):
    print(f"Class {u}: {c}")

# Loads the dataset, batchsize and shuffles the dataset

train_loader = DataLoader(train_dataset, batch_size=64, sampler=train_sampler)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

class_counter = Counter()

for inputs, labels in train_loader:
    class_counter.update(labels.tolist())

print("Sampled class counts in one epoch:")
for cls in sorted(class_counter.keys()):
    print(f"Class {cls}: {class_counter[cls]}")

# Load ResNet18

model = models.resnet18(weights=models.ResNet18_Weights.IMAGENET1K_V1)

# This replaces the final layer of the model to output 5 classes instead of 1000

model.fc = nn.Sequential(
    nn.Linear(512, 256),
    nn.ReLU(),
    nn.Dropout(0.5),
    nn.Linear(256, 3)
)

# Freeze all layers except the last two layers.

for param in model.parameters():
    param.requires_grad = False
for param in model.layer3.parameters():
    param.requires_grad = True
for param in model.layer4.parameters():
    param.requires_grad = True
for param in model.fc.parameters():
    param.requires_grad = True

# Uses cuda if available or it uses cpu

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)

# Loss function and optimizer

criterion = torch.nn.CrossEntropyLoss(label_smoothing=0.1)
optimizer = torch.optim.Adam([
    {"params": model.layer3.parameters(), "lr": 1e-4},
    {"params": model.layer4.parameters(), "lr": 1e-4},
    {"params": model.fc.parameters(), "lr": 1e-3},
])

# Model training

total_epoch = 25
recall_macro = MulticlassRecall(num_classes=3, average="macro").to(device)
precision_macro = MulticlassPrecision(num_classes=3, average="macro").to(device)
specificity_macro = MulticlassSpecificity(num_classes=3, average="macro").to(device)
f1score_macro = MulticlassF1Score(num_classes=3, average="macro").to(device)
train_probs = []
pred_val = []
all_labels = []
for epoch in range(total_epoch):
    model.train()
    recall_macro.reset()
    precision_macro.reset()
    specificity_macro.reset()
    f1score_macro.reset()
    running_loss = 0.0
    correct = 0
    total = 0
    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        
        optimizer.zero_grad()

        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        _, predicted = outputs.max(1)
        if epoch == total_epoch-1:
            probs = torch.softmax(outputs, dim=1)
            train_probs.append(probs.detach().numpy())
            pred_val.append(predicted.detach().numpy())
            all_labels.append(labels.detach().numpy())
        correct += predicted.eq(labels).sum().item()
        total += labels.size(0)
        recall_macro.update(predicted, labels)
        precision_macro.update(predicted, labels)
        specificity_macro.update(predicted, labels)
        f1score_macro.update(predicted, labels)

    recall = recall_macro.compute().item()
    precision = precision_macro.compute().item()
    specificity = specificity_macro.compute().item()
    f1score = f1score_macro.compute().item()
    print(f'Epoch [{epoch+1}/{total_epoch}], Loss: {running_loss/len(train_loader):.4f}, Accuracy: {100 * correct / total:.2f}%, Recall: {recall:.2f}, Precision: {precision:.2f}, Specificity: {specificity:.2f}, F1-Score: {f1score:.2f}')
train_probs = np.concatenate(train_probs, axis=0)
pred_val = np.concatenate(pred_val, axis=0)
all_labels = np.concatenate(all_labels, axis=0)
print("Classification Report:\n", classification_report(all_labels, pred_val, labels=[0,1,2]))
cm = confusion_matrix(all_labels, pred_val, labels=[0,1,2], normalize='true')
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[0,1,2])
disp.plot()
plt.show()

plt.figure(figsize=(8,6))
for c in range(3):
    precision, recall, _ = precision_recall_curve(
        (all_labels == c).astype(int),
        train_probs[:, c]
    )
    plt.plot(recall, precision, label=f"Class {c}")

plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision–Recall Curve (Training – Last Epoch)")
plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(8,6))
for c in range(3):
    false_pos, true_pos, _ = roc_curve(
        (all_labels == c).astype(int),
        train_probs[:, c]
    )
    plt.plot(false_pos, true_pos, label=f"Class {c}")

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive rate")
plt.title("ROC Curve (Training – Last Epoch)")
plt.legend()
plt.grid(True)
plt.show()

model.eval()
recall_macro.reset()
precision_macro.reset()
specificity_macro.reset()
f1score_macro.reset()
correct = 0
total = 0
test_probs = []
pred_val = []
all_labels = []

# Model testing

with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, predicted = outputs.max(1)
        probs = torch.softmax(outputs, dim=1)
        test_probs.append(probs.numpy())
        pred_val.append(predicted.numpy())
        all_labels.append(labels.numpy())
        correct += predicted.eq(labels).sum().item()
        total += labels.size(0)
        recall_macro.update(predicted, labels)
        precision_macro.update(predicted, labels)
        specificity_macro.update(predicted, labels)
        f1score_macro.update(predicted, labels)
    recall = recall_macro.compute().item()
    precision = precision_macro.compute().item()
    specificity = specificity_macro.compute().item()
    f1score = f1score_macro.compute().item()
print(f'Test Accuracy: {100 * correct / total:.2f}%, Recall: {recall:.2f}, Precision: {precision:.2f}, Specificity: {specificity:.2f}, F1-Score: {f1score:.2f}')
test_probs = np.concatenate(test_probs, axis=0)
all_labels = np.concatenate(all_labels, axis=0)
pred_val = np.concatenate(pred_val, axis=0)
print("Classification Report:\n", classification_report(all_labels, pred_val, labels=[0,1,2]))
cm = confusion_matrix(all_labels, pred_val, labels=[0,1,2], normalize='true')
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[0,1,2])
disp.plot()
plt.show()

plt.figure(figsize=(8,6))

for c in range(3):
    precision, recall, _ = precision_recall_curve(
        (all_labels == c).astype(int),
        test_probs[:, c]
    )
    plt.plot(recall, precision, label=f"Class {c}")

plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision–Recall Curve (Test Set)")
plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(8,6))
for c in range(3):
    false_pos, true_pos, _ = roc_curve(
        (all_labels == c).astype(int),
        test_probs[:, c]
    )
    plt.plot(false_pos, true_pos, label=f"Class {c}")

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive rate")
plt.title("ROC Curve (Test Set)")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Class 0: 204
# Class 1: 54
# Class 2: 69
# Sampled class counts in one epoch:
# Class 0: 425
# Class 1: 435
# Class 2: 447
# Epoch [1/25], Loss: 1.1097, Accuracy: 41.93%, Recall: 0.42, Precision: 0.42, Specificity: 0.71, F1-Score: 0.42
# Epoch [2/25], Loss: 1.0332, Accuracy: 47.90%, Recall: 0.48, Precision: 0.48, Specificity: 0.74, F1-Score: 0.47
# Epoch [3/25], Loss: 0.9962, Accuracy: 51.95%, Recall: 0.52, Precision: 0.52, Specificity: 0.76, F1-Score: 0.51
# Epoch [4/25], Loss: 0.9169, Accuracy: 60.67%, Recall: 0.60, Precision: 0.60, Specificity: 0.80, F1-Score: 0.60
# Epoch [5/25], Loss: 0.9441, Accuracy: 57.31%, Recall: 0.57, Precision: 0.57, Specificity: 0.79, F1-Score: 0.57
# Epoch [6/25], Loss: 0.8643, Accuracy: 64.96%, Recall: 0.65, Precision: 0.65, Specificity: 0.82, F1-Score: 0.65
# Epoch [7/25], Loss: 0.8318, Accuracy: 67.25%, Recall: 0.67, Precision: 0.67, Specificity: 0.84, F1-Score: 0.67
# Epoch [8/25], Loss: 0.8350, Accuracy: 67.25%, Recall: 0.67, Precision: 0.67, Specificity: 0.84, F1-Score: 0.67
# Epoch [9/25], Loss: 0.8308, Accuracy: 66.34%, Recall: 0.66, Precision: 0.66, Specificity: 0.83, F1-Score: 0.66
# Epoch [10/25], Loss: 0.7557, Accuracy: 73.60%, Recall: 0.74, Precision: 0.74, Specificity: 0.87, F1-Score: 0.74
# Epoch [11/25], Loss: 0.7364, Accuracy: 75.36%, Recall: 0.75, Precision: 0.75, Specificity: 0.88, F1-Score: 0.75
# Epoch [12/25], Loss: 0.7747, Accuracy: 72.00%, Recall: 0.72, Precision: 0.72, Specificity: 0.86, F1-Score: 0.72
# Epoch [13/25], Loss: 0.6781, Accuracy: 77.35%, Recall: 0.77, Precision: 0.78, Specificity: 0.89, F1-Score: 0.78
# Epoch [14/25], Loss: 0.6445, Accuracy: 80.80%, Recall: 0.81, Precision: 0.81, Specificity: 0.90, F1-Score: 0.81
# Epoch [15/25], Loss: 0.6381, Accuracy: 80.57%, Recall: 0.80, Precision: 0.81, Specificity: 0.90, F1-Score: 0.80
# Epoch [16/25], Loss: 0.6347, Accuracy: 81.56%, Recall: 0.81, Precision: 0.81, Specificity: 0.91, F1-Score: 0.81
# Epoch [17/25], Loss: 0.6429, Accuracy: 80.64%, Recall: 0.81, Precision: 0.81, Specificity: 0.90, F1-Score: 0.81
# Epoch [18/25], Loss: 0.5996, Accuracy: 84.54%, Recall: 0.84, Precision: 0.85, Specificity: 0.92, F1-Score: 0.84
# Epoch [19/25], Loss: 0.5836, Accuracy: 84.70%, Recall: 0.84, Precision: 0.85, Specificity: 0.92, F1-Score: 0.85
# Epoch [20/25], Loss: 0.5535, Accuracy: 86.84%, Recall: 0.87, Precision: 0.87, Specificity: 0.93, F1-Score: 0.87
# Epoch [21/25], Loss: 0.5813, Accuracy: 85.77%, Recall: 0.86, Precision: 0.86, Specificity: 0.93, F1-Score: 0.86
# Epoch [22/25], Loss: 0.5357, Accuracy: 88.98%, Recall: 0.89, Precision: 0.89, Specificity: 0.94, F1-Score: 0.89
# Epoch [23/25], Loss: 0.5220, Accuracy: 88.91%, Recall: 0.89, Precision: 0.89, Specificity: 0.94, F1-Score: 0.89
# Epoch [24/25], Loss: 0.5035, Accuracy: 89.90%, Recall: 0.90, Precision: 0.90, Specificity: 0.95, F1-Score: 0.90
# Epoch [25/25], Loss: 0.4933, Accuracy: 90.97%, Recall: 0.91, Precision: 0.91, Specificity: 0.95, F1-Score: 0.91
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.88      0.90       439
#            1       0.91      0.92      0.91       455
#            2       0.90      0.93      0.92       413
#
#     accuracy                           0.91      1307
#    macro avg       0.91      0.91      0.91      1307
# weighted avg       0.91      0.91      0.91      1307
# Test Accuracy: 68.50%, Recall: 0.56, Precision: 0.62, Specificity: 0.80, F1-Score: 0.58
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.77      0.83      0.80       204
#            1       0.29      0.31      0.30        54
#            2       0.79      0.55      0.65        69
#
#     accuracy                           0.69       327
#    macro avg       0.62      0.56      0.58       327
# weighted avg       0.69      0.69      0.68       327
